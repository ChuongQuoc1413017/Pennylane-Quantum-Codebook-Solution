# %%
import pennylane as qp

# %%
dev = qp.device("default.qubit", wires=1)

@qp.qnode(dev)
def apply_z_to_plus():
    """Write a circuit that applies PauliZ to the |+> state and returns
    the measurement outcome probabilities.
    """
    ##################
    # YOUR CODE HERE #
    ##################

    # CREATE THE |+> STATE
    qp.Hadamard(wires=0)

    # APPLY PAULI Z
    qp.PauliZ(wires=0)

    # RETURN THE STATE
    return qp.state()

# %%
dev = qp.device("default.qubit", wires=1)

@qp.qnode(dev)
def fake_z():
    """Use RZ to produce the same action as Pauli Z on the |+> state."""
    ##################
    # YOUR CODE HERE #
    ##################

    # CREATE THE |+> STATE
    qp.Hadamard(wires=0)

    # APPLY RZ
    qp.RZ(np.pi, wires=0)

    # RETURN THE STATE
    return qp.state()

# %% [markdown]
# <img src="data:image/svg+xml;base64,..." alt="" width="500" height="3" />

# %%
dev = qp.device("default.qubit", wires=1)

@qp.qnode(dev)
def many_rotations():
    """Implement the circuit depicted above and return the quantum state."""
    qp.Hadamard(0)
    qp.S(0)
    qp.adjoint(qp.T(0))
    qp.RZ(0.3, wires=0)
    qp.adjoint(qp.S(0))

    # RETURN THE STATE
    return qp.state()
