# %%
import pennylane as qp
import numpy as np

# %%
num_wires = 2
dev = qp.device("default.qubit", wires=num_wires)

@qp.qnode(dev)
def apply_cnot(basis_id):
    """Apply a CNOT to |basis_id>.

    Args:
        basis_id (int): An integer value identifying the basis state to construct.

    Returns:
        np.array[complex]: The resulting state after applying CNOT|basis_id>.
    """

    # Prepare the basis state |basis_id>
    bits = [int(x) for x in np.binary_repr(basis_id, width=num_wires)]
    qp.BasisState(bits, wires=[0, 1])

    ##################
    # YOUR CODE HERE #
    ##################

    # APPLY THE CNOT
    qp.CNOT(wires=[0, 1])

    return qp.state()

##################
# YOUR CODE HERE #
##################

# REPLACE THE BIT STRINGS VALUES BELOW WITH THE CORRECT ONES
cnot_truth_table = {"00": "00", "01": "01", "10": "11", "11": "10"}

# Run your QNode with various inputs to help fill in your truth table
print(apply_cnot(0))
# Out:
# [1.+0.j 0.+0.j 0.+0.j 0.+0.j]

# %% [markdown]
# <img src="data:image/svg+xml;base64,..." alt="" width="500" height="34" />

# %%
dev = qp.device("default.qubit", wires=2)

@qp.qnode(dev)
def apply_h_cnot():
    ##################
    # YOUR CODE HERE #
    ##################

    # APPLY THE OPERATIONS IN THE CIRCUIT
    qp.Hadamard(wires=0)
    qp.CNOT(wires=[0, 1])

    return qp.state()

print(apply_h_cnot())

##################
# YOUR CODE HERE #
##################

# SET THIS AS 'separable' OR 'entangled' BASED ON YOUR OUTCOME
state_status = "entangled"
# Out:
# [0.70710678+0.j 0.        +0.j 0.        +0.j 0.70710678+0.j]

# %% [markdown]
# <img src="data:image/svg+xml;base64,..." alt="" width="500" height="90" />

# %%
dev = qp.device("default.qubit", wires=3)

@qp.qnode(dev)
def controlled_rotations(theta, phi, omega):
    """Implement the circuit above and return measurement outcome probabilities.

    Args:
        theta (float): A rotation angle
        phi (float): A rotation angle
        omega (float): A rotation angle

    Returns:
        np.array[float]: Measurement outcome probabilities of the 3-qubit
        computational basis states.
    """

    ##################
    # YOUR CODE HERE #
    ##################

    # APPLY THE OPERATIONS IN THE CIRCUIT AND RETURN MEASUREMENT PROBABILITIES
    qp.Hadamard(wires=0)
    qp.CRX(theta, wires = [0, 1])
    qp.CRY(phi, wires = [1, 2])
    qp.CRZ(omega, wires = [2, 0])

    return qp.probs(wires = [0, 1, 2])

theta, phi, omega = 0.1, 0.2, 0.3
print(controlled_rotations(theta, phi, omega))
# Out:
# [5.00000000e-01 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  4.98751041e-01 0.00000000e+00 1.23651067e-03 1.24480103e-05]
