# %%
import pennylane as qp
qml = qp
import numpy as np

# %% [markdown]
# <img src="data:image/svg+xml;base64,..." alt="" width="500" height="56" />

# %%
n_bits = 4
dev = qp.device("default.qubit", wires=n_bits)

@qp.qnode(dev)
def naive_circuit():
    """Create a uniform superposition and return the probabilities.

    Returns: 
        array[float]: Probabilities for observing different outcomes.
    """
    for wire in range(n_bits):

        ##################
        # YOUR CODE HERE #
        ##################

        qp.Hadamard(wires=wire) # REPLACE PASS

    return qp.probs(wires=range(n_bits))
